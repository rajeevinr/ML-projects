# %%
# AIzaSyACRAy0-W0Rt5b53I3kh4cbz2kS2VDDH4A

# %%
import os
user_secrets = os.getenv('AIzaSyACRAy0-W0Rt5b53I3kh4cbz2kS2VDDH4A')
from IPython.display import display
from IPython.display import Markdown
import pathlib
import textwrap

# apiKey = user_secrets.get_secret("AIzaSyACRAy0-W0Rt5b53I3kh4cbz2kS2VDDH4A")

# def to_markdown(text):
#   text = text.replace('•', '  *')
#   return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
import google.generativeai as genai

genai.configure(api_key = 'AIzaSyACRAy0-W0Rt5b53I3kh4cbz2kS2VDDH4A')

# %%
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("What is the meaning of life?")
to_markdown(response.text)
# Out:
# > The meaning of life is a profound and subjective question that has been contemplated by philosophers, thinkers, and individuals throughout history. Various philosophies, religions, and cultures have their own unique perspectives on this question, leading to a multitude of interpretations and beliefs.
# >
# > **Philosophical Perspectives:**
# >
# > * **Existentialism:** Emphasizes the individual's freedom and responsibility to create their own meaning in life.
# > * **Utilitarianism:** Proposes that the meaning of life lies in maximizing happiness and well-being for the greatest number of people.
# > * **Stoicism:** Focuses on living in accordance with nature and accepting what cannot be changed, leading to inner peace and resilience.
# > * **Buddhism:** Teaches that life is about recognizing the nature of suffering and finding a path to liberation from it.
# > * **Nihilism:** Holds that life is inherently meaningless and has no ultimate purpose.
# >
# > **Religious Perspectives:**
# >
# > * **Monotheism:** Believes in a singular divine being who creates and sustains life, with the meaning of life being to worship and serve that being.
# > * **Polytheism:** Recognizes multiple deities who play different roles in the creation and purpose of life.
# > * **Atheism:** Rejects the existence of any deities, suggesting that life has no inherent meaning beyond what individuals assign to it.
# >
# > **Cultural Perspectives:**
# >
# > * **Confucianism:** Emphasizes familial harmony, respect for elders, and the fulfillment of one's societal roles.
# > * **Taoism:** Promotes living in balance with nature, embracing simplicity, and seeking inner peace.
# > * **Hinduism:** Believes in reincarnation and karma, with the goal of achieving liberation from the cycle of rebirth.
# > * **African philosophy:** Often focuses on communal values, the interconnectedness of life, and the importance of ancestral wisdom.
# >
# > **Personal Perspectives:**
# >
# > Ultimately, the meaning of life is a highly personal and subjective experience. It can vary based on one's values, beliefs, goals, and life experiences. Some common themes that emerge in personal interpretations include:
# >
# > * Finding purpose and fulfillment in personal relationships, work, or hobbies.
# > * Making a positive impact on the world through service or advocacy.
# > * Pursuing personal growth and self-actualization.
# > * Seeking experiences that bring joy, meaning, and a sense of connection.
# >
# > It is important to note that the meaning of life is not something that can be definitively defined or objectively proven. It is a journey of exploration, discovery, and interpretation that is unique to each individual.

# %%
# View the response candidates
response.candidates
# Out:
# [content {
#   parts {
#     text: "The meaning of life is a profound and subjective question that has been contemplated by philosophers, thinkers, and individuals throughout history. Various philosophies, religions, and cultures have their own unique perspectives on this question, leading to a multitude of interpretations and beliefs.\n\n**Philosophical Perspectives:**\n\n* **Existentialism:** Emphasizes the individual\'s freedom and responsibility to create their own meaning in life.\n* **Utilitarianism:** Proposes that the meaning of life lies in maximizing happiness and well-being for the greatest number of people.\n* **Stoicism:** Focuses on living in accordance with nature and accepting what cannot be changed, leading to inner peace and resilience.\n* **Buddhism:** Teaches that life is about recognizing the nature of suffering and finding a path to liberation from it.\n* **Nihilism:** Holds that life is inherently meaningless and has no ultimate purpose.\n\n**Religious Perspectives:**\n\n* **Monotheism:** Believes in a singular divine being who creates and sustains life, with the meaning of life being to worship and serve that being.\n* **Polytheism:** Recognizes multiple deities who play different roles in the creation and purpose of life.\n* **Atheism:** Rejects the existence of any deities, suggesting that life has no inherent meaning beyond what individuals assign to it.\n\n**Cultural Perspectives:**\n\n* **Confucianism:** Emphasizes familial harmony, respect for elders, and the fulfillment of one\'s societal roles.\n* **Taoism:** Promotes living in balance with nature, embracing simplicity, and seeking inner peace.\n* **Hinduism:** Believes in reincarnation and karma, with the goal of achieving liberation from the cycle of rebirth.\n* **African philosophy:** Often focuses on communal values, the interconnectedness of life, and the importance of ancestral wisdom.\n\n**Personal Perspectives:**\n\nUltimately, the meaning of life is a highly personal and subjective experience. It can vary based on one\'s values, beliefs, goals, and life experiences. Some common themes that emerge in personal interpretations include:\n\n* Finding purpose and fulfillment in personal relationships, work, or hobbies.\n* Making a positive impact on the world through service or advocacy.\n* Pursuing personal growth and self-actualization.\n* Seeking experiences that bring joy, meaning, and a sense of connection.\n\nIt is important to note that the meaning of life is not something that can be definitively defined or objectively proven. It is a journey of exploration, discovery, and interpretation that is unique to each individual."
#   }
#   role: "model"
# }
# finish_reason: STOP
# index: 0
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }
# ]

# %%
response.prompt_feedback

# %%
# !curl -o image.jpg https://t0.gstatic.com/licensed-image?q=tbn:ANd9GcQ_Kevbk21QBRy-PgB4kQpS79brbmmEG7m3VOTShAn4PecDU5H5UxrJxE3Dw1JiaG17V88QIol19-3TM2wCHw

# %%
import PIL.Image

img = PIL.Image.open('image.jpg')
img

# %%
model = genai.GenerativeModel('gemini-pro-vision')

# %%
response = model.generate_content(img)

to_markdown(response.text)

# %%
response = model.generate_content(["Write a short, engaging blog post based on this picture. It should include a description of the meal in the photo and talk about my journey meal prepping.", img])
to_markdown(response.text)

# %%
model = genai.GenerativeModel('gemini-pro')
chat = model.start_chat(history=[])
chat

# %%
response = chat.send_message("In one sentence, explain how a computer works to a young child.")
to_markdown(response.text)

# %%
chat.history

# %%
response = chat.send_message("Okay, how about a more detailed explanation to a high schooler?")
to_markdown(response.text)

# %%
for message in chat.history:
  display(to_markdown(f'**{message.role}**: {message.parts[0].text}'))

# %%
result = genai.embed_content(
    model="models/embedding-001",
    content="What is the meaning of life?",
    task_type="retrieval_document",
    title="Embedding of single string")

# 1 input > 1 vector output
print(str(result['embedding'])[:50], '... TRIMMED]')

# %%
result = genai.embed_content(
    model="models/embedding-001",
    content=[
      'What is the meaning of life?',
      'How much wood would a woodchuck chuck?',
      'How does the brain work?'],
    task_type="retrieval_document",
    title="Embedding of list of strings")

# A list of inputs > A list of vectors output
for v in result['embedding']:
  print(str(v)[:50], '... TRIMMED ...')

# %%
response.candidates[0].content

# %%
result = genai.embed_content(
    model = 'models/embedding-001',
    content = response.candidates[0].content)

# 1 input > 1 vector output
print(str(result['embedding'])[:50], '... TRIMMED ...')

# %%
chat.history

# %%
result = genai.embed_content(
    model = 'models/embedding-001',
    content = chat.history)

# 1 input > 1 vector output
for i,v in enumerate(result['embedding']):
  print(str(v)[:50], '... TRIMMED...')

# %%
import google.ai.generativelanguage as glm

# %%
model = genai.GenerativeModel('gemini-pro-vision')
response = model.generate_content(
    glm.Content(
        parts = [
            glm.Part(text="Write a short, engaging blog post based on this picture."),
            glm.Part(
                inline_data=glm.Blob(
                    mime_type='image/jpeg',
                    data=pathlib.Path('image.jpg').read_bytes()
                )
            ),
        ],
    )
)
to_markdown(response.text[:100] + "... [TRIMMED] ...")

# %%
model = genai.GenerativeModel('gemini-pro')

messages = [
    {'role':'user',
     'parts': ["Briefly explain how a computer works to a young child."]}
]
response = model.generate_content(messages)

to_markdown(response.text)

# %%
messages.append({'role':'model',
                 'parts':[response.text]})

messages.append({'role':'user',
                 'parts':["Okay, how about a more detailed explanation to a high school student?"]})

response = model.generate_content(messages)

to_markdown(response.text)

# %%
response = model.generate_content(
    'Tell me a story about a magic backpack.',
    generation_config=genai.types.GenerationConfig(
        # Only one candidate for now.
        candidate_count=1,
        stop_sequences=['x'],
        max_output_tokens=20,
        temperature=1.0)
)

# %%
response = model.generate_content("What is the meaning of life?", stream=True)
for chunk in response:
  print(chunk.text)
  print("_"*80)

# %%
print(response.candidates)
